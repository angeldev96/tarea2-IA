# %%
import pandas as pd

# %%
df1 = pd.read_csv("countries_of_the_world.csv")
df2 = pd.read_csv("unemployment analysis.csv")

# %%
df1['Country Name'] = df1['Country Name'].apply(lambda x: x.replace('"', ''))

# %%
dftemp = df2.loc[: , ["Country Name", "Country Code", "1991"]]

# %%
df3 = pd.merge(df1, df2, on = 'Country Name', how='outer')

# %%
df3
# Out:
#         Country Name                               Region  Population  \
# 0        Afghanistan        ASIA (EX. NEAR EAST)           31056997.0
# 1            Albania  EASTERN EUROPE                        3581655.0
# 2            Algeria  NORTHERN AFRICA                      32930091.0
# 3    American Samoa   OCEANIA                                 57794.0
# 4           Andorra   WESTERN EUROPE                          71201.0
# ..               ...                                  ...         ...
# 453            Samoa                                  NaN         NaN
# 454      Yemen, Rep.                                  NaN         NaN
# 455     South Africa                                  NaN         NaN
# 456           Zambia                                  NaN         NaN
# 457         Zimbabwe                                  NaN         NaN
#
#      Area (sq. mi.) Pop. Density (per sq. mi.) Coastline (coast/area ratio)  \
# ...

# %%
dfnew = pd.DataFrame()
for y in df3.columns[ 21: ]:
    dftemp = df3.loc[ : , ["Country Name","Region","Country Code",y] ]
    dftemp["Year"] = y
    dftemp.columns = ['Country Name', "Region", 'Country Code', 'Value', 'Year']
    dftemp = dftemp.loc[ : , ['Country Name', "Region", 'Country Code', 'Year', 'Value'] ]
    
    dfnew = pd.concat([dfnew, dftemp])

# %%
dfnew
# Out:
#         Country Name                               Region Country Code  Year  \
# 0        Afghanistan        ASIA (EX. NEAR EAST)                   AFG  1991
# 1            Albania  EASTERN EUROPE                               ALB  1991
# 2            Algeria  NORTHERN AFRICA                              DZA  1991
# 3    American Samoa   OCEANIA                                      NaN  1991
# 4           Andorra   WESTERN EUROPE                               NaN  1991
# ..               ...                                  ...          ...   ...
# 453            Samoa                                  NaN          WSM  2021
# 454      Yemen, Rep.                                  NaN          YEM  2021
# 455     South Africa                                  NaN          ZAF  2021
# 456           Zambia                                  NaN          ZMB  2021
# 457         Zimbabwe                                  NaN          ZWE  2021
#
#      Value
# 0    10.65
# 1    10.31
# ...

# %%
dfnew.to_csv('df5.csv')
